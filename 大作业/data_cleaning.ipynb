# %%
# %pip install jieba
# Out:
# ...
#      ━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/19.2 MB 1.7 MB/s  0:00:10
#   WARNING: Attempting to resume incomplete download (3.4 MB/19.2 MB, attempt 1)
#   Resuming download jieba-0.42.1.tar.gz (3.4 MB/19.2 MB)
#      ━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/19.2 MB 991.4 kB/s  0:00:13m0m
#   WARNING: Attempting to resume incomplete download (7.3 MB/19.2 MB, attempt 2)
#   Resuming download jieba-0.42.1.tar.gz (7.3 MB/19.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━ 10.2/19.2 MB 1.2 MB/s  0:00:08m
#   WARNING: Attempting to resume incomplete download (10.2 MB/19.2 MB, attempt 3)
#   Resuming download jieba-0.42.1.tar.gz (10.2 MB/19.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━ 13.3/19.2 MB 1.3 MB/s  0:00:05
#   WARNING: Attempting to resume incomplete download (13.3 MB/19.2 MB, attempt 4)
#   Resuming download jieba-0.42.1.tar.gz (13.3 MB/19.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━ 18.6/19.2 MB 1.2 MB/s  0:00:01m
# ...
